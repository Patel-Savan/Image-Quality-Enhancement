# %%
# !pip install numpy opencv-python tensorflow scikit-learn matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from tqdm import tqdm
from skimage.metrics import peak_signal_noise_ratio as psnr, structural_similarity as ssim
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# Define dataset paths
dataset_path = r"C:\Users\ASUS\Desktop\University\sem-4\FER2013_Sample_100"
train_path = os.path.join(dataset_path, "train")
test_path = os.path.join(dataset_path, "test")

# Define noisy dataset paths
noisy_dataset_path = r"C:\Users\ASUS\Desktop\University\sem-4\FER2013_Sample_100_Noisy_Images"
noisy_train_path = os.path.join(noisy_dataset_path, "train")
noisy_test_path = os.path.join(noisy_dataset_path, "test")

# Ensure noisy dataset directories exist
for path in [noisy_train_path, noisy_test_path]:
    if not os.path.exists(path):
        os.makedirs(path)

# %%
def display_sample_images(folder_path, num_images=5):
    categories = os.listdir(folder_path)
    fig, axes = plt.subplots(len(categories), num_images, figsize=(10, 10))

    # for i, category in enumerate(categories):
    #     category_path = os.path.join(folder_path, category)
    #     image_files = os.listdir(category_path)[:num_images]

    #     for j, image_file in enumerate(image_files):
    #         img_path = os.path.join(category_path, image_file)
    #         img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE) 
    #         img = cv2.resize(img, (48, 48)) 

    #         axes[i, j].imshow(img, cmap='gray')
    #         axes[i, j].axis("off")

    #     axes[i, 0].set_ylabel(category, fontsize=12)

    category_path = os.path.join(folder_path, "neutral")
    image_files = os.listdir(category_path)[:num_images]

    for j, image_file in enumerate(image_files):
        img_path = os.path.join(category_path, image_file)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE) 
        img = cv2.resize(img, (48, 48)) 
        
        axes[j].imshow(img, cmap='gray')
        axes[j].axis("off")

    axes[0].set_ylabel("neutral", fontsize=12)

    plt.tight_layout()
    plt.show()

display_sample_images(train_path, num_images=5)

# %%
# Function to add Gaussian noise
def add_gaussian_noise(image, mean=0, std=0.05):  
    noise = np.random.normal(mean, std, image.shape)
    noisy_image = 255*(image + noise)
    # noisy_image = cv2.add(image, noise)  # Add noise to the image
    return noisy_image

# Function to process images and save noisy versions
def process_images(input_folder, output_folder, category="neutral"):
    category_path = os.path.join(input_folder, category)
    noisy_category_path = os.path.join(output_folder, category)

    # Ensure category subfolder exists in noisy images
    if not os.path.exists(noisy_category_path):
        os.makedirs(noisy_category_path)

    # Process images inside category folder
    for img_name in tqdm(os.listdir(category_path), desc=f"Processing {category} in {output_folder}"):
        img_path = os.path.join(category_path, img_name)
        noisy_img_path = os.path.join(noisy_category_path, img_name)

        # Read and process image
        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            continue  # Skip unreadable images
            
        noisy_image = add_gaussian_noise(image / 255.0)

        # Save noisy image
        cv2.imwrite(noisy_img_path, noisy_image)

# Apply noise to both train and test datasets for neutral category
process_images(train_path, noisy_train_path, category="neutral")
process_images(test_path, noisy_test_path, category="neutral")

print("Noisy images successfully generated and saved in 'FER2013_Noisy_Images' folder.")
# Out:
# Processing neutral in C:\Users\ASUS\Desktop\University\sem-4\FER2013_Sample_100_Noisy_Images\train: 100%|█| 100/100 [00
# Processing neutral in C:\Users\ASUS\Desktop\University\sem-4\FER2013_Sample_100_Noisy_Images\test: 100%|█| 25/25 [00:00
# ✅ Noisy images successfully generated and saved in 'FER2013_Noisy_Images' folder.

# %%
def display_original_and_noisy_images(original_folder, noisy_folder, num_images=5, category="neutral"):
    original_category_path = os.path.join(original_folder, category)
    noisy_category_path = os.path.join(noisy_folder, category)

    if not os.path.exists(noisy_category_path):
        print(f"Skipping {category}, noisy folder not found.")
        return

    fig, axes = plt.subplots(1, num_images * 2, figsize=(15, 5))

    image_files = os.listdir(original_category_path)[:num_images]

    for j, image_file in enumerate(image_files):
        original_img_path = os.path.join(original_category_path, image_file)
        noisy_img_path = os.path.join(noisy_category_path, image_file)

        original_img = cv2.imread(original_img_path, cv2.IMREAD_GRAYSCALE)
        noisy_img = cv2.imread(noisy_img_path, cv2.IMREAD_GRAYSCALE)

        if original_img is None or noisy_img is None:
            continue  # Skip if images are unreadable

        original_img = cv2.resize(original_img, (48, 48))
        noisy_img = cv2.resize(noisy_img, (48, 48))

        # Show original image
        axes[j * 2].imshow(original_img, cmap='gray')
        axes[j * 2].axis("off")
        axes[j * 2].set_title("Original")

        # Show noisy image
        axes[j * 2 + 1].imshow(noisy_img, cmap='gray')
        axes[j * 2 + 1].axis("off")
        axes[j * 2 + 1].set_title("Noisy")

    plt.tight_layout()
    plt.show()

# Display original and noisy images for neutral category
display_original_and_noisy_images(train_path, noisy_train_path, num_images=5, category="neutral")
display_original_and_noisy_images(test_path, noisy_test_path, num_images=5, category="neutral")

# %%
def apply_fft(image):
    """Applies 2D FFT and shifts the zero frequency component to the center, then normalizes."""
    fft_image = np.fft.fft2(image)
    fft_shifted = np.fft.fftshift(fft_image)

    # Normalize real and imaginary parts separately
    real_part = np.real(fft_shifted)
    imag_part = np.imag(fft_shifted)

    real_part = (real_part - np.min(real_part)) / (np.max(real_part) - np.min(real_part))
    imag_part = (imag_part - np.min(imag_part)) / (np.max(imag_part) - np.min(imag_part))

    return real_part, imag_part

def load_images_with_fft(folder_path, category="neutral", image_size=(48, 48)):
    """Loads images, applies FFT, normalizes, and returns as two-channel representation."""
    data = []
    category_path = os.path.join(folder_path, category)

    for img_name in os.listdir(category_path):
        img_path = os.path.join(category_path, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            continue
        img = cv2.resize(img, image_size) / 255.0  # Normalize input before FFT
        real_part, imag_part = apply_fft(img)
        data.append(np.stack([real_part, imag_part], axis=-1))  # Two channels: real + imaginary

    return np.array(data).astype("float32")

# Load FFT-transformed noisy and clean images
X_noisy_fft = load_images_with_fft(noisy_train_path, category="neutral")
X_clean_fft = load_images_with_fft(train_path, category="neutral")

print("FFT Transformed Images Loaded Successfully!")
# Out:
# FFT Transformed Images Loaded Successfully!

# %%
def build_fft_dae():
    input_img = tf.keras.Input(shape=(48, 48, 2))  # 2 channels for real and imaginary parts

    # Encoder 
    x = tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding="same")(input_img)
    x = tf.keras.layers.MaxPooling2D((2, 2), padding="same")(x)

    # Decoder 
    x = tf.keras.layers.Conv2DTranspose(64, (3, 3), activation="relu", padding="same")(x)
    x = tf.keras.layers.UpSampling2D((2, 2))(x)
    output_img = tf.keras.layers.Conv2D(2, (3, 3), activation="linear", padding="same")(x)

    model = tf.keras.Model(input_img, output_img)
    model.compile(optimizer="adam", loss="mse")
    
    return model

# Build the DAE model
fft_dae = build_fft_dae()
fft_dae.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 48, 48, 2)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 48, 48, 64)          │           1,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 24, 24, 64)          │          36,928 │
# ...

# %%
X_noisy_train = X_noisy_fft
X_clean_train = X_clean_fft

# K-Fold Cross-Validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)
best_val_loss = float("inf")

initial_weights = fft_dae.get_weights()  # Store initial weights

for train_idx, val_idx in kf.split(X_noisy_train):
    X_train_fold, X_val_fold = X_noisy_train[train_idx], X_noisy_train[val_idx]
    y_train_fold, y_val_fold = X_clean_train[train_idx], X_clean_train[val_idx]

    fft_dae.set_weights(initial_weights)  # Reset weights before training each fold

    # Checkpoint & Early Stopping
    checkpoint = ModelCheckpoint("temp_best_fft_model.keras", monitor="val_loss", save_best_only=True, verbose=0)
    early_stopping = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

    history = fft_dae.fit(X_train_fold, y_train_fold, epochs=500, batch_size=16,
                          validation_data=(X_val_fold, y_val_fold), callbacks=[checkpoint, early_stopping], verbose=0)

    fft_dae.load_weights("temp_best_fft_model.keras")  # Load best weights for this fold
    val_loss = min(history.history["val_loss"])

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        fft_dae.save("best_fft_dae_model.keras")  # Save the best model

print("Best FFT-based model saved as 'best_fft_dae_model.keras'")
# Out:
# Best FFT-based model saved as 'best_fft_dae_model.keras'

# %%
best_model = tf.keras.models.load_model("best_fft_dae_model.keras")

X_unseen_fft = load_images_with_fft(noisy_test_path, category="neutral")
y_unseen_fft = load_images_with_fft(test_path, category="neutral")

# Ensure FFT data is properly formatted
X_unseen_test = X_unseen_fft
X_unseen_test = np.squeeze(X_unseen_test)  # Remove any extra dimensions if needed

# Predict denoised images in the frequency domain
denoised_fft_images = best_model.predict(X_unseen_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 11
#       8 X_unseen_test = np.squeeze(X_unseen_test)  # Remove any extra dimensions if needed
#      10 # Predict denoised images in the frequency domain
# ---> 11 denoised_fft_images = best_model.predict(X_unseen_test)
#      13 # Convert back to spatial domain using inverse FFT
#      14 denoised_images = np.array([
#      15     apply_ifft(denoised_fft_images[i, ..., 0], denoised_fft_images[i, ..., 1])
#      16     for i in range(len(denoised_fft_images))
#      17 ])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# ...

# %%
def apply_ifft(real_part, imag_part):
    """Applies inverse FFT to reconstruct the image from frequency domain."""
    complex_image = real_part + 1j * imag_part
    ifft_shifted = np.fft.ifftshift(complex_image)
    image = np.fft.ifft2(ifft_shifted)
    image = np.abs(image)  # Take magnitude to get real values
    return (image - np.min(image)) / (np.max(image) - np.min(image)) * 255  # Normalize to [0,255]

denoised_images = np.array([
    apply_ifft(denoised_fft_images[i, ..., 0], denoised_fft_images[i, ..., 1])
    for i in range(len(denoised_fft_images))
]).astype(np.uint8)

print("Noisy images successfully denoised and converted back to spatial domain!")

# %%
from skimage.metrics import peak_signal_noise_ratio as psnr, structural_similarity as ssim

# Performance Metrics Calculation (MSE, PSNR, SSIM)
def calculate_metrics(original, denoised):
    metrics = {"MSE": [], "PSNR": [], "SSIM": []}

    for i in range(original.shape[0]):
        orig, denoised_img = original[i].squeeze(), denoised[i].squeeze()

        # Mean Squared Error
        mse_value = np.mean((orig - denoised_img) ** 2)
        metrics["MSE"].append(mse_value)

        # Peak Signal-to-Noise Ratio
        psnr_value = psnr(orig, denoised_img, data_range=orig.max() - orig.min())
        metrics["PSNR"].append(psnr_value)

        # Structural Similarity Index
        ssim_value = ssim(orig, denoised_img, data_range=orig.max() - orig.min())
        metrics["SSIM"].append(ssim_value)

    # Compute mean values for each metric
    return {key: np.mean(values) for key, values in metrics.items()}

# %%
# Load the best model
best_model = tf.keras.models.load_model("best_fft_dae_model.keras")

# Load 20% unseen test data
X_unseen = load_images_with_fft(noisy_test_path, category = "neutral")
y_unseen = load_images_with_fft(test_path, category = "neutral")

# Predict denoised images using the trained model
denoised_images = best_model.predict(X_unseen)

# Calculate metrics (MSE, PSNR, SSIM)
denoised_metrics = calculate_metrics(y_unseen, denoised_images)
   
# Print results
print("Comparison of Original Image and Denoised Image:")
for metric, value in denoised_metrics.items():
    print(f"{metric}: {value:.4f}")

noisy_metrics = calculate_metrics(y_unseen, X_unseen)
# Print results
print("Comparison of Original Image and Noisy Image:")
for metric, value in noisy_metrics.items():
    print(f"{metric}: {value:.4f}")
# Out:
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 9
#       6 y_unseen = load_images_with_fft(test_path, category = "neutral")
#       8 # Predict denoised images using the trained model
# ----> 9 denoised_images = best_model.predict(X_unseen)
#      11 # Calculate metrics (MSE, PSNR, SSIM)
#      12 denoised_metrics = calculate_metrics(y_unseen, denoised_images)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
# ...

# %%
def visualize_results(original, noisy, denoised):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 3, 1)
    plt.imshow(original, cmap="gray")
    plt.title("Original")

    plt.subplot(1, 3, 2)
    plt.imshow(noisy, cmap="gray")
    plt.title("Noisy")

    plt.subplot(1, 3, 3)
    plt.imshow(denoised, cmap="gray")
    plt.title("Denoised")

    plt.show()

# Pick a test sample
idx = np.random.randint(len(y_unseen_fft))
original = cv2.imread(os.path.join(test_path, "neutral", os.listdir(test_path + "/neutral")[idx]), cv2.IMREAD_GRAYSCALE)
noisy = cv2.imread(os.path.join(noisy_test_path, "neutral", os.listdir(noisy_test_path + "/neutral")[idx]), cv2.IMREAD_GRAYSCALE)
denoised = denoised_images[idx]

visualize_results(original, noisy, denoised)
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
